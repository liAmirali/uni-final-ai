# %% [markdown]
# # Quick Start Guide
#
# This notebook demonstrates how to use the new clean project structure.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

import json

# %% [markdown]
# ## Generate Base Personas

# %%
from generators import generate_base_persona

base_personas = [generate_base_persona() for _ in range(3)]
print(json.dumps(base_personas[0], indent=2, ensure_ascii=False))

# %% [markdown]
# ## Complete Personas Using LLM

# %%
from generators import PersonaGenerator
from utils import LLMClient, create_openai_client

client = create_openai_client()
llm_client = LLMClient(client)
persona_generator = PersonaGenerator(llm_client)

# Uncomment to run:
# personas = persona_generator.generate_with_stats(count=5, model='gpt-5-nano')
